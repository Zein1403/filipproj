# %%
# inventory_app.py
import streamlit as st
import csv
import os
from datetime import datetime

# File name
filename_pemasangan = 'Pemasangan.csv'
filename_pelepasan = 'Pelepasan.csv'

# Create CSV with header if not exists
if not os.path.exists(filename_pemasangan):
    with open(filename, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Tanggal','Kode filter', 'Jam pemasangan', 'Flow Awal', 'Elapsed Time Awal','Nama Petugas Pemasangan'])
if not os.path.exists(filename_pelepasan):
    with open(filename, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Tanggal','Kode filter', 'Jam pelepasan', 'Flow Akhir', 'Elapsed Time Akhir','Nama Petugas Pelepasan'])

st.title("📦 Sampling Filipina")

# Sidebar menu
menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat CSV"])
# Out:
# 2025-08-11 13:31:29.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 13:31:29.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import csv
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from datetime import datetime


scope = ["https://spreadsheets.google.com/feeds",
         "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("test-data-filipin-3cd188664241.json", scope)
client = gspread.authorize(creds)



# File names
filename_pemasangan = 'Pemasangan.csv'
filename_pelepasan = 'Pelepasan.csv'

# Create CSV with header if not exists
if not os.path.exists(filename_pemasangan):
    with open(filename_pemasangan, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Tanggal Pemasangan', 'Kode filter', 'Jam pemasangan', 'Flow Awal', 'Elapsed Time Awal', 'Nama Petugas Pemasangan'])

if not os.path.exists(filename_pelepasan):
    with open(filename_pelepasan, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Tanggal Pelepasan', 'Kode filter', 'Jam pelepasan', 'Flow Akhir', 'Elapsed Time Akhir', 'Nama Petugas Pelepasan'])

st.title("📦 Sampling Filipina")

# Sidebar menu
menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat CSV"])

# Load CSV data
def load_data(file_path):
    with open(file_path, 'r', newline='') as f:
        return list(csv.DictReader(f))

if menu == "Pemasangan":
    data = load_data(filename_pemasangan)
elif menu == "Pelepasan":
    data = load_data(filename_pelepasan)

# Save CSV data
def save_data(file_path, rows, fieldnames):
    with open(file_path, 'w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

if menu == "Pemasangan":
    fieldnames = ['Tanggal Peamasangan','Kode filter', 'Jam pemasangan', 'Flow Awal', 'Elapsed Time Awal','Nama Petugas Pemasangan']
    save_data(filename_pemasangan, data, fieldnames)

elif menu == "Pelepasan":
    fieldnames = ['Tanggal Pelepasan','Kode filter', 'Jam pelepasan', 'Flow Akhir', 'Elapsed Time Akhir','Nama Petugas Pelepasan']
    save_data(filename_pelepasan, data, fieldnames)

if menu == "Pemasangan" :
    st.header("Pemasangan")
    kode = st.text_input
    flow = st.number_input
    elapsed = st.number_input
    petugas =st.text_input
    tanggal = datetime.now().strftime("%Y-%m-%d ")
    jam = datetime.now().strftime("%H:%M:%S")

    if st.button("Simpan"):
        save_data_append('Pemasangan.csv', {
            
            'Tanggal Peamasangan' : tanggal,
            'Kode filter' : kode,
            'Jam pemasangan' : jam,
            'Flow Awal' : flow,
            'Elapsed Time Awal' : elapsed,
            'Nama Petugas Pemasangan' : petugas
            
        })
        st.success("Data berhasil disimpan (tanpa cek duplikat)")


if menu == "Pelepasan" :
    st.header("Pelepasan")
    kode = st.text_input
    flow = st.number_input
    elapsed = st.number_input
    petugas =st.text_input
    tanggal = datetime.now().strftime("%Y-%m-%d ")
    jam = datetime.now().strftime("%H:%M:%S")

    if st.button("Simpan"):
        save_data_append('Pemasangan.csv', {
            
            'Tanggal Pelepasan' : tanggal,
            'Kode filter' : kode,
            'Jam pelepasan' : jam,
            'Flow Akhir' : flow,
            'Elapsed Time Akhir' : elapsed,
            'Nama Petugas pelepas' : petugas
            
        })
        st.success("Data berhasil disimpan (tanpa cek duplikat)")

elif menu == "Lihat CSV":
    st.header("📄 Data Inventory")
    rows = load_data()
    if rows:
        st.dataframe(rows)
    else:
        st.info("📂 Data masih kosong.")
# Out:
# 2025-08-13 09:07:56.743 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.234
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\New\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-13 09:07:59.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.252 Session state does not function when running a script without `streamlit run`
# 2025-08-13 09:07:59.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-13 09:07:59.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import csv
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from datetime import datetime


scope = ["https://spreadsheets.google.com/feeds",
         "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("test-data-filipin-3cd188664241.json", scope)
client = gspread.authorize(creds)
SPREADSHEET_ID = "1D9R_x2rt8hyBaEOj8ytbj9YvwxFz7X60vUvn-8vQbvk"

sheet_pemasangan = client.open_by_key(SPREADSHEET_ID).worksheet("Pemasangan")
sheet_pelepasan = client.open_by_key(SPREADSHEET_ID).worksheet("Pelepasan")


st.title("📦 Sampling Filipina")

menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"])

if menu == "Pemasangan":
    st.header("Form Pemasangan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pemasangan = st.time_input("Jam pemasangan")
    flow_awal = st.number_input("Flow Awal", min_value=0.0)
    elapsed_awal = st.number_input("Elapsed Time Awal", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pemasangan")

    if st.button("Simpan Pemasangan"):
        sheet_pemasangan.append_row([
            str(tanggal), kode_filter, str(jam_pemasangan),
            flow_awal, elapsed_awal, petugas
        ])
        st.success("Data pemasangan disimpan ke Google Sheets ✅")

elif menu == "Pelepasan":
    st.header("Form Pelepasan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pelepasan = st.time_input("Jam pelepasan")
    flow_akhir = st.number_input("Flow Akhir", min_value=0.0)
    elapsed_akhir = st.number_input("Elapsed Time Akhir", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pelepasan")

    if st.button("Simpan Pelepasan"):
        sheet_pelepasan.append_row([
            str(tanggal), kode_filter, str(jam_pelepasan),
            flow_akhir, elapsed_akhir, petugas
        ])
        st.success("Data pelepasan disimpan ke Google Sheets ✅")

elif menu == "Lihat Data":
    st.subheader("Data Pemasangan")
    pemasangan_data = sheet_pemasangan.get_all_values()
    st.dataframe(pemasangan_data)

    st.subheader("Data Pelepasan")
    pelepasan_data = sheet_pelepasan.get_all_values()
    st.dataframe(pelepasan_data)
    st.title("📦 Sampling Filipina")

menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"])

if menu == "Pemasangan":
    st.header("Form Pemasangan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pemasangan = st.time_input("Jam pemasangan")
    flow_awal = st.number_input("Flow Awal", min_value=0.0)
    elapsed_awal = st.number_input("Elapsed Time Awal", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pemasangan")

    if st.button("Simpan Pemasangan"):
        sheet_pemasangan.append_row([
            str(tanggal), kode_filter, str(jam_pemasangan),
            flow_awal, elapsed_awal, petugas
        ])
        st.success("Data pemasangan disimpan ke Google Sheets ✅")

elif menu == "Pelepasan":
    st.header("Form Pelepasan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pelepasan = st.time_input("Jam pelepasan")
    flow_akhir = st.number_input("Flow Akhir", min_value=0.0)
    elapsed_akhir = st.number_input("Elapsed Time Akhir", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pelepasan")

    if st.button("Simpan Pelepasan"):
        sheet_pelepasan.append_row([
            str(tanggal), kode_filter, str(jam_pelepasan),
            flow_akhir, elapsed_akhir, petugas
        ])
        st.success("Data pelepasan disimpan ke Google Sheets ✅")

elif menu == "Lihat Data":
    st.subheader("Data Pemasangan")
    pemasangan_data = sheet_pemasangan.get_all_values()
    st.dataframe(pemasangan_data)

    st.subheader("Data Pelepasan")
    pelepasan_data = sheet_pelepasan.get_all_values()
    st.dataframe(pelepasan_data)
# Out:
# 2025-08-14 14:42:15.610 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.050
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\New\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-14 14:42:18.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.110 Session state does not function when running a script without `streamlit run`
# 2025-08-14 14:42:18.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 14:42:18.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"])

if menu == "Pemasangan":
    st.header("Form Pemasangan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pemasangan = st.time_input("Jam pemasangan")
    flow_awal = st.number_input("Flow Awal", min_value=0.0)
    elapsed_awal = st.number_input("Elapsed Time Awal", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pemasangan")

    if st.button("Simpan Pemasangan"):
        sheet_pemasangan.append_row([
            str(tanggal), kode_filter, str(jam_pemasangan),
            flow_awal, elapsed_awal, petugas
        ])
        st.success("Data pemasangan disimpan ke Google Sheets ✅")

elif menu == "Pelepasan":
    st.header("Form Pelepasan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pelepasan = st.time_input("Jam pelepasan")
    flow_akhir = st.number_input("Flow Akhir", min_value=0.0)
    elapsed_akhir = st.number_input("Elapsed Time Akhir", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pelepasan")

    if st.button("Simpan Pelepasan"):
        sheet_pelepasan.append_row([
            str(tanggal), kode_filter, str(jam_pelepasan),
            flow_akhir, elapsed_akhir, petugas
        ])
        st.success("Data pelepasan disimpan ke Google Sheets ✅")

elif menu == "Lihat Data":
    st.subheader("Data Pemasangan")
    pemasangan_data = sheet_pemasangan.get_all_values()
    st.dataframe(pemasangan_data)

    st.subheader("Data Pelepasan")
    pelepasan_data = sheet_pelepasan.get_all_values()
    st.dataframe(pelepasan_data)
    st.title("📦 Sampling Filipina")

# %%
menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"])

if menu == "Pemasangan":
    st.header("Form Pemasangan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pemasangan = st.time_input("Jam pemasangan")
    flow_awal = st.number_input("Flow Awal", min_value=0.0)
    elapsed_awal = st.number_input("Elapsed Time Awal", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pemasangan")

    if st.button("Simpan Pemasangan"):
        sheet_pemasangan.append_row([
            str(tanggal), kode_filter, str(jam_pemasangan),
            flow_awal, elapsed_awal, petugas
        ])
        st.success("Data pemasangan disimpan ke Google Sheets ✅")

elif menu == "Pelepasan":
    st.header("Form Pelepasan")
    tanggal = st.date_input("Tanggal", datetime.now().date())
    kode_filter = st.text_input("Kode filter")
    jam_pelepasan = st.time_input("Jam pelepasan")
    flow_akhir = st.number_input("Flow Akhir", min_value=0.0)
    elapsed_akhir = st.number_input("Elapsed Time Akhir", min_value=0.0)
    petugas = st.text_input("Nama Petugas Pelepasan")

    if st.button("Simpan Pelepasan"):
        sheet_pelepasan.append_row([
            str(tanggal), kode_filter, str(jam_pelepasan),
            flow_akhir, elapsed_akhir, petugas
        ])
        st.success("Data pelepasan disimpan ke Google Sheets ✅")

elif menu == "Lihat Data":
    st.subheader("Data Pemasangan")
    pemasangan_data = sheet_pemasangan.get_all_values()
    st.dataframe(pemasangan_data)

    st.subheader("Data Pelepasan")
    pelepasan_data = sheet_pelepasan.get_all_values()
    st.dataframe(pelepasan_data
