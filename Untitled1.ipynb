# %%
import streamlit as st
import csv
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from datetime import datetime


scope = ["https://spreadsheets.google.com/feeds",
         "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("test-data-filipin-3cd188664241.json", scope)
client = gspread.authorize(creds)
SPREADSHEET_ID = "1D9R_x2rt8hyBaEOj8ytbj9YvwxFz7X60vUvn-8vQbvk"

sheet_pemasangan = client.open_by_key(SPREADSHEET_ID).worksheet("Sheet3")
sheet_pelepasan = client.open_by_key(SPREADSHEET_ID).worksheet("Sheet3")


st.title("📦 Sampling Filipina")

menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"])

if menu == "Pemasangan":
    st.header("Form Pemasangan")
    kode_filter = st.text_input("Kode filter")
    flow_awal = st.number_input("Flow Awal", min_value=0.0)
    elapsed_awal = st.number_input("Elapsed Time Awal", min_value=0.0)
    if st.button("Simpan Pemasangan"):
        # Find existing row for the kode_filter
        records = sheet.get_all_values()
        row_index = None
        for i, row in enumerate(records):
            if len(row) > 1 and row[1] == kode_filter:  # Column B = Kode Filter
                row_index = i + 1  # gspread rows start at 1
                break

        if row_index is None:  
            # If kode_filter not found, add a new row at the end
            row_index = len(records) + 1

        # Prepare data for A–F columns
        pemasangan_data = [
            str(tanggal), kode_filter, str(jam_pemasangan), flow_awal, elapsed_awal, nama_petugas
        ]

        # Update A–F in the row
        sheet.update(f"A{row_index}:F{row_index}", [pemasangan_data])
        st.success(f"Data pemasangan untuk {kode_filter} berhasil disimpan di baris {row_index}!")
# Out:
# 2025-08-14 15:22:56.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-14 15:22:56.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import csv
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from datetime import datetime


scope = ["https://spreadsheets.google.com/feeds",
         "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("test-data-filipin-3cd188664241.json", scope)
client = gspread.authorize(creds)
SPREADSHEET_ID = "1D9R_x2rt8hyBaEOj8ytbj9YvwxFz7X60vUvn-8vQbvk"

sheet_pemasangan = client.open_by_key(SPREADSHEET_ID).worksheet("Sheet3")
sheet_pelepasan = client.open_by_key(SPREADSHEET_ID).worksheet("Sheet3")


st.title("📦 Sampling Filipina")

menu = st.sidebar.radio("Menu", ["Pemasangan", "Pelepasan", "Lihat Data"], key="main_menu")

# --- Pemasangan ---
if menu == "Pemasangan":
    st.subheader("Form Pemasangan")
    tanggal = st.date_input("Tanggal", datetime.today())
    kode_filter = st.text_input("Kode Filter")
    jam_pemasangan = st.time_input("Jam Pemasangan")
    flow_awal = st.text_input("Flow Awal")
    elapsed_awal = st.text_input("Elapsed Time Awal")
    nama_petugas = st.text_input("Nama Petugas Pemasangan")

    if st.button("Simpan Pemasangan"):
        # Find existing row for the kode_filter
        records = sheet.get_all_values()
        row_index = None
        for i, row in enumerate(records):
            if len(row) > 1 and row[1] == kode_filter:  # Column B = Kode Filter
                row_index = i + 1  # gspread rows start at 1
                break

        if row_index is None:  
            # If kode_filter not found, add a new row at the end
            row_index = len(records) + 1

        # Prepare data for A–F columns
        pemasangan_data = [
            str(tanggal), kode_filter, str(jam_pemasangan), flow_awal, elapsed_awal, nama_petugas
        ]

        # Update A–F in the row
        sheet.update(f"A{row_index}:F{row_index}", [pemasangan_data])
        st.success(f"Data pemasangan untuk {kode_filter} berhasil disimpan di baris {row_index}!")
elif menu == "Pelepasan":
    st.subheader("Form Pelepasan")
    kode_filter = st.text_input("Kode Filter")  # match pemasangan
    flow_akhir = st.text_input("Flow Akhir")
    elapsed_akhir = st.text_input("Elapsed Time Akhir")
    nama_petugas = st.text_input("Nama Petugas Pengganti(jika ada)")

    if st.button("Simpan Pelepasan"):
        # Find row for kode_filter
        records = sheet.get_all_values()
        row_index = None
        for i, row in enumerate(records):
            if len(row) > 1 and row[1] == kode_filter:  # compare with kode_filter
                row_index = i + 1
                break

        if row_index is None:
            st.error(f"Kode filter {kode_filter} belum ada di data pemasangan!")
        else:
            # Prepare data for H–J columns
            pelepasan_data = [flow_akhir, elapsed_akhir, nama_petugas]
            sheet.update(f"H{row_index}:J{row_index}", [pelepasan_data])
            st.success(f"Data pelepasan untuk {kode_filter} berhasil disimpan di baris {row_index}!")

# --- Lihat Data ---
elif menu == "Lihat Data":
    data = sheet.get_all_records()
    st.dataframe(data)
# Out:
# 2025-08-17 08:30:14.525 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.864
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\New\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-17 08:30:18.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.882 Session state does not function when running a script without `streamlit run`
# 2025-08-17 08:30:18.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:18.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 08:30:19.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
